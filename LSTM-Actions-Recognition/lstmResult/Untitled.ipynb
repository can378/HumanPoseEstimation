# %%
# !python pose_lstm_realtime.py
# Out:
# Successfully opened camera 0
#
# ...
# 1/1 [==============================] - 3s 3s/step
#
# ...
# 1/1 [==============================] - 1s 560ms/step
#
# ...
# 1/1 [==============================] - 0s 53ms/step
#
# ...
# 1/1 [==============================] - 0s 36ms/step
#
# ...
# 1/1 [==============================] - 0s 40ms/step
#
# ...
# 1/1 [==============================] - 0s 48ms/step
#
# ...
# 1/1 [==============================] - 0s 60ms/step
#
# ...
# 1/1 [==============================] - 0s 53ms/step
#
# ...
# 1/1 [==============================] - 0s 49ms/step
#
# ...
# 1/1 [==============================] - 0s 58ms/step
#
# ...
# 1/1 [==============================] - 0s 54ms/step
#
# ...
# 1/1 [==============================] - 0s 65ms/step
#
# ...
# 1/1 [==============================] - 0s 55ms/step
#
# ...
# 1/1 [==============================] - 0s 47ms/step
#
# ...
# 1/1 [==============================] - 0s 57ms/step
#
# ...
# 1/1 [==============================] - 0s 48ms/step
#
# ...
# 1/1 [==============================] - 0s 49ms/step
#
# ...
